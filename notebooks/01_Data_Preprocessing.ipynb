# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("data/Delivery Dataset.csv")

# %%
df.shape
# Out:
# (40207, 19)

# %%
df.shape
# Out:
# (40207, 19)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40207 entries, 0 to 40206
# Data columns (total 19 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Delivery_person_ID           40207 non-null  object
#  1   Delivery_person_Age          38562 non-null  float64
#  2   Delivery_person_Ratings      38520 non-null  float64
#  3   Restaurant_latitude          40207 non-null  float64
#  4   Restaurant_longitude         40207 non-null  float64
#  5   Delivery_location_latitude   40207 non-null  float64
#  6   Delivery_location_longitude  40207 non-null  float64
#  7   Order_Date                   40207 non-null  object
#  8   Time_Orderd                  38676 non-null  object
#  9   Time_Order_picked            40207 non-null  object
#  10  Weather_conditions           39662 non-null  object
#  11  Road_traffic_density         39675 non-null  object
#  12  Vehicle_condition            40207 non-null  int64
#  13  Type_of_order                40207 non-null  object
#  14  Type_of_vehicle              40207 non-null  object
#  15  multiple_deliveries          39357 non-null  float64
#  16  Festival                     40033 non-null  object
#  17  City_Type                    39174 non-null  object
#  18  Time_taken (min)             40207 non-null  int64
# dtypes: float64(7), int64(2), object(10)
# memory usage: 5.8+ MB

# %%
df
# Out:
#       Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0          DEHRES17DEL01                 36.0                      4.2
# 1          KOCRES16DEL01                 21.0                      4.7
# 2         PUNERES13DEL03                 23.0                      4.7
# 3         LUDHRES15DEL02                 34.0                      4.3
# 4          KNPRES14DEL02                 24.0                      4.7
# ...                  ...                  ...                      ...
# 40202     BANGRES16DEL03                 28.0                      4.9
# 40203   RANCHIRES16DEL01                 35.0                      4.2
# 40204     CHENRES08DEL03                 30.0                      4.9
# 40205    COIMBRES11DEL01                 20.0                      4.7
# 40206   RANCHIRES09DEL02                 23.0                      4.9
#
#        Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0                30.327968             78.046106                   30.397968
# 1                10.003064             76.307589                   10.043064
# 2                18.562450             73.916619                   18.652450
# 3                30.899584             75.809346                   30.919584
# 4                26.463504             80.372929                   26.593504
# ...                    ...                   ...                         ...
# 40202            13.029198             77.570997                   13.059198
# 40203            23.371292             85.327872                   23.481292
# 40204            13.022394             80.242439                   13.052394
# 40205            11.001753             76.986241                   11.041753
# 40206            23.351058             85.325731                   23.431058
#
#        Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked  \
# 0                        78.116106  12-02-2022       21:55             22:10
# 1                        76.347589  13-02-2022       14:55             15:05
# 2                        74.006619  04-03-2022       17:30             17:40
# 3                        75.829346  13-02-2022       09:20             09:30
# 4                        80.502929  14-02-2022       19:50             20:05
# ...                            ...         ...         ...               ...
# 40202                    77.600997  30-03-2022       21:55       0.916666667
# 40203                    85.437872  08-03-2022       21:45             21:55
# 40204                    80.272439  11-03-2022       23:50          24:05:00
# 40205                    77.026241  07-03-2022       13:35             13:40
# 40206                    85.405731  02-03-2022       17:10             17:15
#
#       Weather_conditions Road_traffic_density  Vehicle_condition  \
# 0                    Fog                  Jam                  2
# 1                 Stormy                 High                  1
# 2             Sandstorms               Medium                  1
# 3             Sandstorms                  Low                  0
# 4                    Fog                  Jam                  1
# ...                  ...                  ...                ...
# 40202         Sandstorms                  Jam                  1
# 40203              Windy                  Jam                  2
# 40204             Cloudy                  Low                  1
# 40205             Cloudy                 High                  0
# 40206                Fog               Medium                  2
#
#       Type_of_order Type_of_vehicle  multiple_deliveries Festival  \
# 0             Snack      motorcycle                  3.0       No
# 1              Meal      motorcycle                  1.0       No
# 2            Drinks         scooter                  1.0       No
# 3            Buffet      motorcycle                  0.0       No
# 4             Snack         scooter                  1.0       No
# ...             ...             ...                  ...      ...
# 40202          Meal         scooter                  1.0       No
# 40203        Drinks      motorcycle                  1.0       No
# 40204        Drinks         scooter                  0.0       No
# 40205         Snack      motorcycle                  1.0       No
# 40206         Snack         scooter                  1.0       No
#
#            City_Type  Time_taken (min)
# 0      Metropolitian                46
# 1      Metropolitian                23
# 2      Metropolitian                21
# 3      Metropolitian                20
# 4      Metropolitian                41
# ...              ...               ...
# 40202  Metropolitian                29
# 40203  Metropolitian                33
# 40204  Metropolitian                16
# 40205  Metropolitian                26
# 40206  Metropolitian                36
#
# [40207 rows x 19 columns]

# %%
round(df.isna().sum()/df.shape[0] * 100 , 2)
# Out:
# Delivery_person_ID             0.00
# Delivery_person_Age            4.09
# Delivery_person_Ratings        4.20
# Restaurant_latitude            0.00
# Restaurant_longitude           0.00
# Delivery_location_latitude     0.00
# Delivery_location_longitude    0.00
# Order_Date                     0.00
# Time_Orderd                    3.81
# Time_Order_picked              0.00
# Weather_conditions             1.36
# Road_traffic_density           1.32
# Vehicle_condition              0.00
# Type_of_order                  0.00
# Type_of_vehicle                0.00
# multiple_deliveries            2.11
# Festival                       0.43
# City_Type                      2.57
# Time_taken (min)               0.00
# dtype: float64

# %%
df.drop(index= df[df['Delivery_person_ID'].isna()].index , inplace=True)

# %%
df.isna().sum()
# Out:
# Delivery_person_ID                0
# Delivery_person_Age            1645
# Delivery_person_Ratings        1687
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                    1531
# Time_Order_picked                 0
# Weather_conditions              545
# Road_traffic_density            532
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries             850
# Festival                        174
# City_Type                      1033
# Time_taken (min)                  0
# dtype: int64

# %% [markdown]
# Fetching Valuable Features from `Delivery_person_ID`
#
# like:
#
# `JAPRES04DEL01`
# - **JAP** → City code →**Jaipur**
# - **RES04** → Region / hub / zone → **Zone 04**
# - **DEL01** → Delivery person → **Agent 01**

# %%
df['Delivery_person_ID']
# Out:
# 0           DEHRES17DEL01
# 1           KOCRES16DEL01
# 2          PUNERES13DEL03
# 3          LUDHRES15DEL02
# 4           KNPRES14DEL02
#                ...
# 40202      BANGRES16DEL03
# 40203    RANCHIRES16DEL01
# 40204      CHENRES08DEL03
# 40205     COIMBRES11DEL01
# 40206    RANCHIRES09DEL02
# Name: Delivery_person_ID, Length: 40207, dtype: object

# %%
df['Delivery_person_ID'].str[:-10].unique()
# Out:
# array(['DEH', 'KOC', 'PUNE', 'LUDH', 'KNP', 'MUM', 'MYS', 'HYD', 'KOL',
#        'RANCHI', 'COIMB', 'CHEN', 'JAP', 'SUR', 'BANG', 'GOA', 'AGR',
#        'ALH', 'BANGR', 'VAD', 'AURG', 'AGRR', 'INDO', 'SURR', 'KOCR',
#        'MYSR', 'LUDHR', 'DEHR', 'HYDR', 'MUMR', 'RANCHIR', 'JAPR',
#        'INDOR', 'CHENR', 'PUNER', 'VADR', 'COIMBR', 'BHP', 'KNPR', 'GOAR',
#        'BHPR', 'AURGR', 'KOLR'], dtype=object)

# %%
city = df['Delivery_person_ID'].str[:-10].apply(lambda x : x[:-1] if x.endswith("R") else x)
df.insert(1 , "City" , city)

# %%
city_mapping = {
    "INDO": "Indore",
    "BANG": "Bangalore",
    "COIMB": "Coimbatore",
    "CHEN": "Chennai",
    "HYD": "Hyderabad",
    "RANCHI": "Ranchi",
    "MYS": "Mysore",
    "DEH": "Dehradun",
    "KOC": "Kochi",
    "PUNE": "Pune",
    "LUDH": "Ludhiana",
    "KNP": "Kanpur",
    "MUM": "Mumbai",
    "KOL": "Kolkata",
    "JAP": "Jaipur",
    "SUR": "Surat",
    "SU": "Surat",
    "GOA": "Goa",
    "AURG": "Aurangabad",
    "AGR": "Agra",
    "AG": "Agra",
    "VAD": "Vadodara",
    "ALH": "Prayagraj",
    "BHP": "Bhopal"
}

# %%
df['City'] = df['City'].map(city_mapping)

# %%
df['City'].nunique()
# Out:
# 22

# %%
df.sample()
# Out:
#       Delivery_person_ID     City  Delivery_person_Age  \
# 10415     CHENRES18DEL01  Chennai                 24.0
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude  \
# 10415                      5.0            12.981615             80.231598
#
#        Delivery_location_latitude  Delivery_location_longitude  Order_Date  \
# 10415                   12.991615                    80.241598  19-03-2022
#
#       Time_Orderd Time_Order_picked Weather_conditions Road_traffic_density  \
# 10415       09:15             09:30              Sunny                  Low
#
#        Vehicle_condition Type_of_order Type_of_vehicle  multiple_deliveries  \
# 10415                  1        Drinks      motorcycle                  0.0
#
#       Festival      City_Type  Time_taken (min)
# 10415       No  Metropolitian                21

# %%
zone = df['Delivery_person_ID'].str[-10:-5].str.replace('RES' , "Zone").str.replace('ES010' , "Zone10").str.strip()

df.insert(2 , "Zone" , zone)

# %%
df.sample()
# Out:
#       Delivery_person_ID    City    Zone  Delivery_person_Age  \
# 18556      MUMRES17DEL02  Mumbai  Zone17                 30.0
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude  \
# 18556                      4.6            19.121999             72.908493
#
#        Delivery_location_latitude  Delivery_location_longitude  Order_Date  \
# 18556                   19.251999                    73.038493  27-03-2022
#
#       Time_Orderd Time_Order_picked Weather_conditions Road_traffic_density  \
# 18556       23:10             23:15         Sandstorms                  Low
#
#        Vehicle_condition Type_of_order Type_of_vehicle  multiple_deliveries  \
# 18556                  0        Drinks      motorcycle                  0.0
#
#       Festival City_Type  Time_taken (min)
# 18556       No     Urban                20

# %%
df['Delivery_person_ID'].str[-2:]
# Out:
# 0        01
# 1        01
# 2        03
# 3        02
# 4        02
#          ..
# 40202    03
# 40203    01
# 40204    03
# 40205    01
# 40206    02
# Name: Delivery_person_ID, Length: 40207, dtype: object

# %%
agent = df['Delivery_person_ID'].str[-2:].str.strip()   

df.insert(3 , "Delivery_Agent" , agent)

# %%
df['Restaurant_latitude'] = df['Restaurant_latitude'].apply(lambda x : -x if x < 0 else x)

df['Restaurant_longitude'] = df['Restaurant_longitude'].apply(lambda x : -x if x < 0 else x)

# %%
df.shape
# Out:
# (40207, 22)

# %%
px.scatter_geo(
    df,
    lat="Restaurant_latitude",
    lon="Restaurant_longitude"
)

# %%
px.scatter_geo(
    df,
    lat="Delivery_location_latitude",
    lon="Delivery_location_longitude"
)

# %%
df.isna().sum().loc[lambda x : x > 0]
# Out:
# Delivery_person_Age        1645
# Delivery_person_Ratings    1687
# Time_Orderd                1531
# Weather_conditions          545
# Road_traffic_density        532
# multiple_deliveries         850
# Festival                    174
# City_Type                  1033
# dtype: int64

# %%
df['Delivery_person_Age'].describe()
# Out:
# count    38562.000000
# mean        29.644572
# std          5.814019
# min         15.000000
# 25%         25.000000
# 50%         30.000000
# 75%         35.000000
# max         50.000000
# Name: Delivery_person_Age, dtype: float64

# %%
df['Delivery_person_Age'] = df['Delivery_person_Age'].fillna(df['Delivery_person_Age'].mean())

# %%
df.isna().sum().loc[lambda x : x > 0]
# Out:
# Delivery_person_Ratings    1687
# Time_Orderd                1531
# Weather_conditions          545
# Road_traffic_density        532
# multiple_deliveries         850
# Festival                    174
# City_Type                  1033
# dtype: int64

# %%
# Converting DType of Order_Date from object to datetime
df['Order_Date'] = pd.to_datetime(df['Order_Date'] , format='mixed')

# %%
# Checking what irrelavant values present in Time_Order_picked feature
invalid_mask_time_ordered = pd.to_datetime(df['Time_Orderd'], errors='coerce').isna()

wrong_values_to = df.loc[invalid_mask_time_ordered, 'Time_Orderd']
wrong_values_to.value_counts()
# Out:
# C:\Users\LeoML\AppData\Local\Temp\ipykernel_10028\2467684873.py:2: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Time_Orderd
# 0.833333333    400
# 0.791666667    377
# 0.875          372
# 1              366
# 0.958333333    361
# 0.75           360
# 0.916666667    355
# 0.416666667    187
# 0.458333333    175
# 0.375          166
# 0.5            147
# 0.625           79
# 0.541666667     74
# 0.583333333     63
# 0.708333333     61
# 0.666666667     46
# Name: count, dtype: int64

# %%
# Function for time correction as there present 24:05 which is not a valid one so converting into 00:05
def correct_time(t):
    if pd.isna(t):
        return t
    if t.startswith("24:"):
        return "00:"+t.split(":")[1]
    return t

df['Time_Order_picked'] = df['Time_Order_picked'].apply(correct_time)

# %%
# Checking what irrelavant values present in Time_Order_picked feature
invalid_mask_time_order_picked = pd.to_datetime(df['Time_Order_picked'], errors='coerce').isna()

wrong_values_top = df.loc[invalid_mask_time_order_picked, 'Time_Order_picked']
wrong_values_top.value_counts()
# Out:
# C:\Users\LeoML\AppData\Local\Temp\ipykernel_10028\837461676.py:2: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Time_Order_picked
# 0.833333333    407
# 0.916666667    382
# 0.875          377
# 1              374
# 0.75           372
# 0.791666667    359
# 0.958333333    344
# 0.375          190
# 0.416666667    182
# 0.5            142
# 0.458333333    135
# 0.625           92
# 0.666666667     83
# 0.541666667     75
# 0.583333333     75
# 0.708333333     63
# Name: count, dtype: int64

# %%
# Converting Time_Ordered and Time_Order_picked feature to datetime and also removing irrelavant values like (0.875 , 0.75 , 1 , etc) using `errors = 'coerce'`

df['Time_Orderd'] = pd.to_datetime(df['Time_Orderd'],
            format="%H:%M",
            errors='coerce').dt.time

df['Time_Order_picked'] = pd.to_datetime(df['Time_Order_picked'],
            format="%H:%M",
            errors='coerce').dt.time

# %%
# Creating order_datetime from Order_Date + Time_Ordered
order_datetime = pd.to_datetime(
    df['Order_Date'].astype('str') + " " + df['Time_Orderd'].astype('str'),
    errors='coerce'
)

df.insert(10 , "Order_Datetime" , order_datetime)

# Creating order_datetime from Order_Date + Time_Order_picked
Pickup_Datetime = pd.to_datetime(
    df['Order_Date'].astype('str') + " " + df['Time_Order_picked'].astype('str'),
    errors='coerce'
)

df.insert(11 , "Pickup_Datetime" , Pickup_Datetime)

# %%
# Some of the pickup done overnight (00:05 or 00:10)
mask = df['Pickup_Datetime'] < df['Order_Datetime']

df.loc[mask , 'Pickup_Datetime'] = df.loc[mask , 'Pickup_Datetime'] + pd.Timedelta(days = 1)

# %%
# Droping Order_Date , Time_Ordered , Time_Order_Picked as we have designed new freatures from them
df.drop(columns=['Order_Date' , "Time_Orderd" , "Time_Order_picked"] , inplace=True)

# %%
# Prep Time 
prep_time_min = ((df['Pickup_Datetime'] - df['Order_Datetime']).dt.total_seconds()/60)

df.insert(12 , "Prep_Time(min)" , prep_time_min)

# %%
# Droping these rows because imputation is risky
df.drop(index=df[df['Order_Datetime'].isna() & df['Pickup_Datetime'].isna()].index  , inplace=True)

# %%
# Statistical Information of Prep Time Feature
df['Prep_Time(min)'].describe()
# Out:
# count    31577.000000
# mean         9.977832
# std          4.085072
# min          5.000000
# 25%          5.000000
# 50%         10.000000
# 75%         15.000000
# max         15.000000
# Name: Prep_Time(min), dtype: float64

# %%
# Median Prep Time
median_prep_time = df['Prep_Time(min)'].median()

# imputing the values of Order_Datetime with Pickup_Time Order_Datetime - median 
mask1 = df['Order_Datetime'].isna() 
df.loc[mask1 , "Order_Datetime"] = df.loc[mask1 , "Pickup_Datetime"] - pd.Timedelta(minutes=median_prep_time)

# imputing the values of Pickup_time with Order_Datetime + median 
mask2 = df['Pickup_Datetime'].isna()
df.loc[mask2 , 'Pickup_Datetime'] = df.loc[mask2 , "Order_Datetime"] + pd.Timedelta(minutes=median_prep_time)

# %%
# updating the Prep Time 
df['Prep_Time(min)'] = (df['Pickup_Datetime'] - df['Order_Datetime']).dt.total_seconds()/60

# %%
df.sample()
# Out:
#       Delivery_person_ID      City    Zone Delivery_Agent  \
# 37420     LUDHRES16DEL03  Ludhiana  Zone16             03
#
#        Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# 37420                 20.0                      4.8            30.895817
#
#        Restaurant_longitude  Delivery_location_latitude  \
# 37420             75.813112                   31.035817
#
#        Delivery_location_longitude      Order_Datetime     Pickup_Datetime  \
# 37420                    75.953112 2022-02-14 22:20:00 2022-02-14 22:25:00
#
#        Prep_Time(min) Weather_conditions Road_traffic_density  \
# 37420             5.0                Fog                  Low
#
#        Vehicle_condition Type_of_order Type_of_vehicle  multiple_deliveries  \
# 37420                  1         Snack      motorcycle                  1.0
#
#       Festival      City_Type  Time_taken (min)
# 37420       No  Metropolitian                23

# %%
# These Features are very important for both analysis and prediction and all of them contains null value and when imputing them with some mode (random way) will decrease the efficiency of the model and imputation will become unreliable 


df.drop(index=df[df['Delivery_person_Ratings'].isna() & df['Weather_conditions'].isna() & df['Road_traffic_density'].isna() & df['multiple_deliveries'].isna()].index , inplace=True)


df.drop(index=df[df['Delivery_person_Ratings'].isna() & df['Weather_conditions'].isna() & df['Road_traffic_density'].isna()].index , inplace=True)

# %%
# Fill missing values in 'City_Type' using group-wise mode based on 'City'
df['City_Type'] = df.groupby('City')['City_Type']\
        .transform(lambda x : x.fillna(x.mode()[0] if not x.mode().empty else 'Unknown'))

# %%
df['Time_taken (min)'].describe()
# Out:
# count    39642.000000
# mean        26.604788
# std          9.265927
# min         10.000000
# 25%         19.000000
# 50%         26.000000
# 75%         33.000000
# max         54.000000
# Name: Time_taken (min), dtype: float64

# %%
df['Delivery_person_Ratings'].mean()
# Out:
# np.float64(4.630250551733091)

# %%
mask3 = df[df['Delivery_person_Ratings'] == 6.0].index
df.loc[mask3 , 'Delivery_person_Ratings'] = np.nan

# %%
df['Delivery_person_Ratings'] = df.groupby('City_Type')['Delivery_person_Ratings'].transform(lambda x: x.fillna(x.median()))

# %%
df['Delivery_person_Ratings'].isna().sum()
# Out:
# np.int64(0)

# %%
indi = df[df['Weather_conditions'].isna()].index

# %%
df['Weather_conditions'] = df.groupby("City")['Weather_conditions'].transform(lambda x : x.fillna(x.mode()[0]))

# %%
df.loc[indi , 'Weather_conditions'].value_counts()
# Out:
# Weather_conditions
# Fog           41
# Cloudy        28
# Stormy        12
# Windy          3
# Sandstorms     2
# Name: count, dtype: int64

# %%
indi2 = df[df['Road_traffic_density'].isna()].index

# %%
indi2
# Out:
# Index([ 2077,  2528,  2568,  3130,  4129,  4529,  4702,  4959,  5186,  5628,
#         8071,  8380,  8410,  8910,  9612,  9810, 10668, 10836, 12038, 12436,
#        13144, 13174, 14035, 14172, 14795, 15105, 15605, 16725, 17089, 17865,
#        18716, 18801, 19669, 19779, 20632, 20729, 20866, 21387, 21987, 22311,
#        22855, 23017, 23525, 23780, 23952, 24044, 24200, 24684, 24740, 25015,
#        25586, 26076, 26186, 26998, 27549, 28195, 28510, 29293, 29583, 30600,
#        30836, 31784, 32718, 33235, 33525, 33536, 34085, 34458, 34465, 35480,
#        35534, 36379, 37115, 37786],
#       dtype='int64')

# %%
df['Road_traffic_density'] = df.groupby('City_Type')['Road_traffic_density'].transform(lambda x : x.fillna(x.mode()[0]))

# %%
df.loc[indi2 , 'Road_traffic_density'].value_counts()
# Out:
# Road_traffic_density
# Jam    56
# Low    18
# Name: count, dtype: int64

# %%
indi3 = df[df['multiple_deliveries'].isna()].index

# %%
df['multiple_deliveries'] = df['multiple_deliveries'].fillna(df['multiple_deliveries'].median())

# %%
df.loc[indi3 , 'multiple_deliveries']
# Out:
# 8        1.0
# 65       1.0
# 111      1.0
# 119      1.0
# 158      1.0
#         ...
# 39653    1.0
# 39660    1.0
# 39756    1.0
# 39822    1.0
# 39910    1.0
# Name: multiple_deliveries, Length: 834, dtype: float64

# %%
df['Festival'] = df['Festival'].transform(lambda x : x.fillna(x.mode()[0]))

# %%
df.isna().sum()
# Out:
# Delivery_person_ID             0
# City                           0
# Zone                           0
# Delivery_Agent                 0
# Delivery_person_Age            0
# Delivery_person_Ratings        0
# Restaurant_latitude            0
# Restaurant_longitude           0
# Delivery_location_latitude     0
# Delivery_location_longitude    0
# Order_Datetime                 0
# Pickup_Datetime                0
# Prep_Time(min)                 0
# Weather_conditions             0
# Road_traffic_density           0
# Vehicle_condition              0
# Type_of_order                  0
# Type_of_vehicle                0
# multiple_deliveries            0
# Festival                       0
# City_Type                      0
# Time_taken (min)               0
# dtype: int64

# %%
df.sample()
# Out:
#     Delivery_person_ID  City    Zone Delivery_Agent  Delivery_person_Age  \
# 264     PUNERES05DEL02  Pune  Zone05             02                 20.0
#
#      Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude  \
# 264                      4.7            18.543626             73.905101
#
#      Delivery_location_latitude  Delivery_location_longitude  \
# 264                   18.623626                    73.985101
#
#          Order_Datetime     Pickup_Datetime  Prep_Time(min)  \
# 264 2022-03-23 17:10:00 2022-03-23 17:15:00             5.0
#
#     Weather_conditions Road_traffic_density  Vehicle_condition Type_of_order  \
# 264         Sandstorms               Medium                  2         Snack
#
#     Type_of_vehicle  multiple_deliveries Festival City_Type  Time_taken (min)
# 264         scooter                  1.0       No     Urban                16

# %%
df
# Out:
#       Delivery_person_ID        City    Zone Delivery_Agent  \
# 0          DEHRES17DEL01    Dehradun  Zone17             01
# 1          KOCRES16DEL01       Kochi  Zone16             01
# 2         PUNERES13DEL03        Pune  Zone13             03
# 3         LUDHRES15DEL02    Ludhiana  Zone15             02
# 4          KNPRES14DEL02      Kanpur  Zone14             02
# ...                  ...         ...     ...            ...
# 40202     BANGRES16DEL03   Bangalore  Zone16             03
# 40203   RANCHIRES16DEL01      Ranchi  Zone16             01
# 40204     CHENRES08DEL03     Chennai  Zone08             03
# 40205    COIMBRES11DEL01  Coimbatore  Zone11             01
# 40206   RANCHIRES09DEL02      Ranchi  Zone09             02
#
#        Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# 0                     36.0                      4.2            30.327968
# 1                     21.0                      4.7            10.003064
# 2                     23.0                      4.7            18.562450
# 3                     34.0                      4.3            30.899584
# 4                     24.0                      4.7            26.463504
# ...                    ...                      ...                  ...
# 40202                 28.0                      4.9            13.029198
# 40203                 35.0                      4.2            23.371292
# 40204                 30.0                      4.9            13.022394
# 40205                 20.0                      4.7            11.001753
# 40206                 23.0                      4.9            23.351058
#
#        Restaurant_longitude  Delivery_location_latitude  \
# 0                 78.046106                   30.397968
# 1                 76.307589                   10.043064
# 2                 73.916619                   18.652450
# 3                 75.809346                   30.919584
# 4                 80.372929                   26.593504
# ...                     ...                         ...
# 40202             77.570997                   13.059198
# 40203             85.327872                   23.481292
# 40204             80.242439                   13.052394
# 40205             76.986241                   11.041753
# 40206             85.325731                   23.431058
#
#        Delivery_location_longitude      Order_Datetime     Pickup_Datetime  \
# 0                        78.116106 2022-12-02 21:55:00 2022-12-02 22:10:00
# 1                        76.347589 2022-02-13 14:55:00 2022-02-13 15:05:00
# 2                        74.006619 2022-04-03 17:30:00 2022-04-03 17:40:00
# 3                        75.829346 2022-02-13 09:20:00 2022-02-13 09:30:00
# 4                        80.502929 2022-02-14 19:50:00 2022-02-14 20:05:00
# ...                            ...                 ...                 ...
# 40202                    77.600997 2022-03-30 21:55:00 2022-03-30 22:05:00
# 40203                    85.437872 2022-08-03 21:45:00 2022-08-03 21:55:00
# 40204                    80.272439 2022-11-03 23:50:00 2022-11-04 00:05:00
# 40205                    77.026241 2022-07-03 13:35:00 2022-07-03 13:40:00
# 40206                    85.405731 2022-02-03 17:10:00 2022-02-03 17:15:00
#
#        Prep_Time(min) Weather_conditions Road_traffic_density  \
# 0                15.0                Fog                  Jam
# 1                10.0             Stormy                 High
# 2                10.0         Sandstorms               Medium
# 3                10.0         Sandstorms                  Low
# 4                15.0                Fog                  Jam
# ...               ...                ...                  ...
# 40202            10.0         Sandstorms                  Jam
# 40203            10.0              Windy                  Jam
# 40204            15.0             Cloudy                  Low
# 40205             5.0             Cloudy                 High
# 40206             5.0                Fog               Medium
#
#        Vehicle_condition Type_of_order Type_of_vehicle  multiple_deliveries  \
# 0                      2         Snack      motorcycle                  3.0
# 1                      1          Meal      motorcycle                  1.0
# 2                      1        Drinks         scooter                  1.0
# 3                      0        Buffet      motorcycle                  0.0
# 4                      1         Snack         scooter                  1.0
# ...                  ...           ...             ...                  ...
# 40202                  1          Meal         scooter                  1.0
# 40203                  2        Drinks      motorcycle                  1.0
# 40204                  1        Drinks         scooter                  0.0
# 40205                  0         Snack      motorcycle                  1.0
# 40206                  2         Snack         scooter                  1.0
#
#       Festival      City_Type  Time_taken (min)
# 0           No  Metropolitian                46
# 1           No  Metropolitian                23
# 2           No  Metropolitian                21
# 3           No  Metropolitian                20
# 4           No  Metropolitian                41
# ...        ...            ...               ...
# 40202       No  Metropolitian                29
# 40203       No  Metropolitian                33
# 40204       No  Metropolitian                16
# 40205       No  Metropolitian                26
# 40206       No  Metropolitian                36
#
# [39642 rows x 22 columns]

# %% [markdown]
# ---

# %% [markdown]
# **Changing Data Type**

# %%
df['Delivery_Agent'] = df['Delivery_Agent'].astype('Int32')

# %%
df['Delivery_person_Age'] = df['Delivery_person_Age'].astype(int)

# %%
df
# Out:
#       Delivery_person_ID        City    Zone  Delivery_Agent  \
# 0          DEHRES17DEL01    Dehradun  Zone17               1
# 1          KOCRES16DEL01       Kochi  Zone16               1
# 2         PUNERES13DEL03        Pune  Zone13               3
# 3         LUDHRES15DEL02    Ludhiana  Zone15               2
# 4          KNPRES14DEL02      Kanpur  Zone14               2
# ...                  ...         ...     ...             ...
# 40202     BANGRES16DEL03   Bangalore  Zone16               3
# 40203   RANCHIRES16DEL01      Ranchi  Zone16               1
# 40204     CHENRES08DEL03     Chennai  Zone08               3
# 40205    COIMBRES11DEL01  Coimbatore  Zone11               1
# 40206   RANCHIRES09DEL02      Ranchi  Zone09               2
#
#        Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# 0                       36                      4.2            30.327968
# 1                       21                      4.7            10.003064
# 2                       23                      4.7            18.562450
# 3                       34                      4.3            30.899584
# 4                       24                      4.7            26.463504
# ...                    ...                      ...                  ...
# 40202                   28                      4.9            13.029198
# 40203                   35                      4.2            23.371292
# 40204                   30                      4.9            13.022394
# 40205                   20                      4.7            11.001753
# 40206                   23                      4.9            23.351058
#
#        Restaurant_longitude  Delivery_location_latitude  \
# 0                 78.046106                   30.397968
# 1                 76.307589                   10.043064
# 2                 73.916619                   18.652450
# 3                 75.809346                   30.919584
# 4                 80.372929                   26.593504
# ...                     ...                         ...
# 40202             77.570997                   13.059198
# 40203             85.327872                   23.481292
# 40204             80.242439                   13.052394
# 40205             76.986241                   11.041753
# 40206             85.325731                   23.431058
#
#        Delivery_location_longitude      Order_Datetime     Pickup_Datetime  \
# 0                        78.116106 2022-12-02 21:55:00 2022-12-02 22:10:00
# 1                        76.347589 2022-02-13 14:55:00 2022-02-13 15:05:00
# 2                        74.006619 2022-04-03 17:30:00 2022-04-03 17:40:00
# 3                        75.829346 2022-02-13 09:20:00 2022-02-13 09:30:00
# 4                        80.502929 2022-02-14 19:50:00 2022-02-14 20:05:00
# ...                            ...                 ...                 ...
# 40202                    77.600997 2022-03-30 21:55:00 2022-03-30 22:05:00
# 40203                    85.437872 2022-08-03 21:45:00 2022-08-03 21:55:00
# 40204                    80.272439 2022-11-03 23:50:00 2022-11-04 00:05:00
# 40205                    77.026241 2022-07-03 13:35:00 2022-07-03 13:40:00
# 40206                    85.405731 2022-02-03 17:10:00 2022-02-03 17:15:00
#
#        Prep_Time(min) Weather_conditions Road_traffic_density  \
# 0                15.0                Fog                  Jam
# 1                10.0             Stormy                 High
# 2                10.0         Sandstorms               Medium
# 3                10.0         Sandstorms                  Low
# 4                15.0                Fog                  Jam
# ...               ...                ...                  ...
# 40202            10.0         Sandstorms                  Jam
# 40203            10.0              Windy                  Jam
# 40204            15.0             Cloudy                  Low
# 40205             5.0             Cloudy                 High
# 40206             5.0                Fog               Medium
#
#        Vehicle_condition Type_of_order Type_of_vehicle  multiple_deliveries  \
# 0                      2         Snack      motorcycle                  3.0
# 1                      1          Meal      motorcycle                  1.0
# 2                      1        Drinks         scooter                  1.0
# 3                      0        Buffet      motorcycle                  0.0
# 4                      1         Snack         scooter                  1.0
# ...                  ...           ...             ...                  ...
# 40202                  1          Meal         scooter                  1.0
# 40203                  2        Drinks      motorcycle                  1.0
# 40204                  1        Drinks         scooter                  0.0
# 40205                  0         Snack      motorcycle                  1.0
# 40206                  2         Snack         scooter                  1.0
#
#       Festival      City_Type  Time_taken (min)
# 0           No  Metropolitian                46
# 1           No  Metropolitian                23
# 2           No  Metropolitian                21
# 3           No  Metropolitian                20
# 4           No  Metropolitian                41
# ...        ...            ...               ...
# 40202       No  Metropolitian                29
# 40203       No  Metropolitian                33
# 40204       No  Metropolitian                16
# 40205       No  Metropolitian                26
# 40206       No  Metropolitian                36
#
# [39642 rows x 22 columns]

# %%
df['Delivery_person_Ratings'].value_counts().sort_index()
# Out:
# Delivery_person_Ratings
# 1.0      32
# 2.5      18
# 2.6      20
# 2.7      21
# 2.8      17
# 2.9      18
# 3.0       6
# 3.1      28
# 3.2      26
# 3.3      23
# 3.4      32
# 3.5     234
# 3.6     191
# 3.7     201
# 3.8     217
# 3.9     173
# 4.0     959
# 4.1    1286
# 4.2    1286
# 4.3    1265
# 4.4    1218
# 4.5    2926
# 4.6    6112
# 4.7    7394
# 4.8    6265
# 4.9    6168
# 5.0    3506
# Name: count, dtype: int64

# %%
df['Delivery_person_Ratings'] = df['Delivery_person_Ratings'].astype('float32')

# %%
df['Vehicle_condition'].value_counts()
# Out:
# Vehicle_condition
# 0    13416
# 1    13103
# 2    13049
# 3       74
# Name: count, dtype: int64

# %%
mapping = {
    0:"poor",
    1:"Average",
    2:"Good",
    3:"Excellent",
}

df['Vehicle_condition'] = df['Vehicle_condition'].map(mapping)

# %%
df['Vehicle_condition']
# Out:
# 0           Good
# 1        Average
# 2        Average
# 3           poor
# 4        Average
#           ...
# 40202    Average
# 40203       Good
# 40204    Average
# 40205       poor
# 40206       Good
# Name: Vehicle_condition, Length: 39642, dtype: object

# %%
df['Prep_Time(min)'] = df['Prep_Time(min)'].astype('Float32')

# %%
df['multiple_deliveries'] = df['multiple_deliveries'].astype('Int8')

# %%
df['Prep_Time(min)'] = df['Prep_Time(min)'].astype('Int16')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 39642 entries, 0 to 40206
# Data columns (total 22 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Delivery_person_ID           39642 non-null  object
#  1   City                         39642 non-null  object
#  2   Zone                         39642 non-null  object
#  3   Delivery_Agent               39642 non-null  Int32
#  4   Delivery_person_Age          39642 non-null  int64
#  5   Delivery_person_Ratings      39642 non-null  float32
#  6   Restaurant_latitude          39642 non-null  float64
#  7   Restaurant_longitude         39642 non-null  float64
#  8   Delivery_location_latitude   39642 non-null  float64
#  9   Delivery_location_longitude  39642 non-null  float64
#  10  Order_Datetime               39642 non-null  datetime64[ns]
#  11  Pickup_Datetime              39642 non-null  datetime64[ns]
#  12  Prep_Time(min)               39642 non-null  Int16
#  13  Weather_conditions           39642 non-null  object
#  14  Road_traffic_density         39642 non-null  object
#  15  Vehicle_condition            39642 non-null  object
#  16  Type_of_order                39642 non-null  object
#  17  Type_of_vehicle              39642 non-null  object
#  18  multiple_deliveries          39642 non-null  Int8
#  19  Festival                     39642 non-null  object
#  20  City_Type                    39642 non-null  object
#  21  Time_taken (min)             39642 non-null  int64
# dtypes: Int16(1), Int32(1), Int8(1), datetime64[ns](2), float32(1), float64(4), int64(2), object(10)
# memory usage: 7.3+ MB

# %%
df.isna().sum()
# Out:
# Delivery_person_ID             0
# City                           0
# Zone                           0
# Delivery_Agent                 0
# Delivery_person_Age            0
# Delivery_person_Ratings        0
# Restaurant_latitude            0
# Restaurant_longitude           0
# Delivery_location_latitude     0
# Delivery_location_longitude    0
# Order_Datetime                 0
# Pickup_Datetime                0
# Prep_Time(min)                 0
# Weather_conditions             0
# Road_traffic_density           0
# Vehicle_condition              0
# Type_of_order                  0
# Type_of_vehicle                0
# multiple_deliveries            0
# Festival                       0
# City_Type                      0
# Time_taken (min)               0
# dtype: int64

# %%
df.drop(columns=['Prep_Time(min)' , 'Delivery_person_ID'] , inplace=True)

# %%
df.to_csv("data/Cleaned Delivery Dataset.csv" , index=False)
